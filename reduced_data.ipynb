# %%
import pandas as pd

# %%
df = pd.read_csv("final_df.csv")

# %%
df
# Out:
#        ROW_ID_x  SUBJECT_ID_x  \
# 0           184         28063
# 1         59801         28063
# 2         59802         28063
# 3        105548         28063
# 4        105549         28063
# ...         ...           ...
# 53753   1363024          7492
# 53754   1363025          7492
# 53755   1671543         32292
# 53756   1671541         32292
# 53757   1671542         32292
#
#                                                     TEXT  \
# 0      Admission Date:  [**2125-2-9**]              D...
# 1      PATIENT/TEST INFORMATION:\nIndication: Aortic ...
# 2      PATIENT/TEST INFORMATION:\nIndication:  Aortic...
# 3      Sinus rhythm.  Frequent atrial premature beats...
# 4      Rhythm is most likely sinus rhythm with freque...
# ...                                                  ...
# 53753  Respiratory Care\nPt remains mechaniclly venti...
# 53754  MICU NPN 0700-1900\n 55 year old woman MICU pt...
# 53755  Nursing Progress Note Addendum.\n\nAt 14:32 th...
# 53756  MICU nursing admission note 4AM\nPt is 83 yo f...
# 53757  Nursing Progress Note.\n\nPt remains a [** 409...
#
#                       DIAGNOSIS
# 0      CONGESTIVE HEART FAILURE
# 1      CONGESTIVE HEART FAILURE
# 2      CONGESTIVE HEART FAILURE
# 3      CONGESTIVE HEART FAILURE
# 4      CONGESTIVE HEART FAILURE
# ...                         ...
# 53753                 PNEUMONIA
# 53754                 PNEUMONIA
# 53755                    SEPSIS
# 53756                    SEPSIS
# 53757                    SEPSIS
#
# [53758 rows x 4 columns]

# %%
df["DIAGNOSIS"].unique()
# Out:
# array(['CONGESTIVE HEART FAILURE', 'PNEUMONIA', 'SEPSIS'], dtype=object)

# %%
test = pd.read_csv("patient_data.csv")
test
# Out:
#          ROW_ID_x  SUBJECT_ID_x  \
# 0             174         22532
# 1             170         22532
# 2           59795         22532
# 3           59796         22532
# 4          106289         22532
# ...           ...           ...
# 1022923    500429         70097
# 1022924    500869         70097
# 1022925    500076         70097
# 1022926    500104         70097
# 1022927    500292         70097
#
#                                                       TEXT  \
# 0        Admission Date:  [**2151-7-16**]       Dischar...
# 1        Admission Date:  [**2151-7-16**]       Dischar...
# 2        PATIENT/TEST INFORMATION:\nIndication: Aortic ...
# 3        PATIENT/TEST INFORMATION:\nIndication: Endocar...
# 4        Atrial fibrillation with a slow ventricular re...
# ...                                                    ...
# 1022923  75 yom with h/o HTN, ^chole, DM on insulin, CK...
# 1022924  Acute coronary syndrome (ACS, unstable angina,...
# 1022925  TITLE:\n   Chief Complaint:\n   24 Hour Events...
# 1022926  Acute coronary syndrome (ACS, unstable angina,...
# 1022927  75 yom with multiple risk factors for CAD with...
#
#                        DIAGNOSIS
# 0        RT LOWER LOBE PNEUMONIA
# 1        RT LOWER LOBE PNEUMONIA
# 2        RT LOWER LOBE PNEUMONIA
# 3        RT LOWER LOBE PNEUMONIA
# 4        RT LOWER LOBE PNEUMONIA
# ...                          ...
# 1022923                   ANGINA
# 1022924                   ANGINA
# 1022925                   ANGINA
# 1022926                   ANGINA
# 1022927                   ANGINA
#
# [1022928 rows x 4 columns]

# %%
unique_counts = test["DIAGNOSIS"].value_counts()
unique_counts
# Out:
# DIAGNOSIS
# NEWBORN                                288251
# PNEUMONIA                               29100
# SEPSIS                                  22429
# CONGESTIVE HEART FAILURE                15755
# CORONARY ARTERY DISEASE                 11770
#                                         ...
# RIGHT WRISTS FRACTURE                       1
# MENINGIOMA, RIGHT SIDE/SDA                  1
# HYPOTENSION;SMALL BOWEL OBSTRUCTION         1
# BREAST CANCER;RECONSTRUCTION,BREAST         1
# OLIGODENDROGLIOMA RIGHT /SDA                1
# Name: count, Length: 8867, dtype: int64

# %%
filtered_counts = unique_counts[unique_counts < 1000]
filtered_counts
# Out:
# DIAGNOSIS
# STROKE                                 972
# RENAL FAILURE                          972
# EXTREME PREMATURITY                    961
# WOUND INFECTION                        961
# SAH                                    959
#                                       ...
# RIGHT WRISTS FRACTURE                    1
# MENINGIOMA, RIGHT SIDE/SDA               1
# HYPOTENSION;SMALL BOWEL OBSTRUCTION      1
# BREAST CANCER;RECONSTRUCTION,BREAST      1
# OLIGODENDROGLIOMA RIGHT /SDA             1
# Name: count, Length: 8776, dtype: int64

# %%
rare_df = test[test['DIAGNOSIS'].isin(['STROKE', 'RENAL FAILURE', 'WOUND INFECTION'])]
rare_df
# Out:
#          ROW_ID_x  SUBJECT_ID_x  \
# 6546          530         54589
# 6547       108816         54589
# 6548       108817         54589
# 6549       108818         54589
# 6550      1255239         54589
# ...           ...           ...
# 1003560   1098780         81728
# 1003561   1097955         81728
# 1003562   1098014         81728
# 1003563   1097956         81728
# 1003564   1098209         81728
#
#                                                       TEXT        DIAGNOSIS
# 6546     Admission Date:  [**2165-10-10**]             ...    RENAL FAILURE
# 6547     Sinus rhythm. Borderline left atrial abnormali...    RENAL FAILURE
# 6548     Artifact is present.  Sinus tachycardia.  Non-...    RENAL FAILURE
# 6549     Sinus rhythm.  The P-R interval is prolonged. ...    RENAL FAILURE
# 6550     [**2165-10-14**] 10:48 AM\n PARACENTESIS DIAG/...    RENAL FAILURE
# ...                                                    ...              ...
# 1003560  [**2138-10-18**] 4:28 PM\n C-SPINE NON-TRAUMA ...  WOUND INFECTION
# 1003561  [**2138-10-13**] 7:23 PM\n CHEST (PA & LAT)   ...  WOUND INFECTION
# 1003562  [**2138-10-14**] 9:51 AM\n SHOULDER (AP, NEUTR...  WOUND INFECTION
# 1003563  WHITE,[**Doctor Last Name **] P.              ...  WOUND INFECTION
# 1003564  [**2138-10-15**] 11:11 AM\n CHEST PORT. LINE P...  WOUND INFECTION
#
# [2905 rows x 4 columns]

# %%
rare_df.to_csv('rare_df.csv', index=False)

# %%
df["DIAGNOSIS"].value_counts()
# Out:
# DIAGNOSIS
# PNEUMONIA                   19699
# SEPSIS                      19323
# CONGESTIVE HEART FAILURE    14736
# Name: count, dtype: int64

# %%
import pandas as pd

# Assuming `final_df` is already loaded

# Set the target sample size per category
sample_size = 200

# Create a new reduced DataFrame by sampling 1000 rows for each diagnosis
reduced_df = pd.concat([
    df[df['DIAGNOSIS'] == diagnosis].sample(n=sample_size, random_state=42)
    for diagnosis in df['DIAGNOSIS'].unique()
])

# Shuffle the resulting dataset (optional)
reduced_df = reduced_df.sample(frac=1, random_state=42).reset_index(drop=True)

# Check the reduced dataset
print(reduced_df['DIAGNOSIS'].value_counts())
print(len(reduced_df))
# Out:
# DIAGNOSIS
# CONGESTIVE HEART FAILURE    200
# SEPSIS                      200
# PNEUMONIA                   200
# Name: count, dtype: int64
# 600

# %%
# Save to CSV
reduced_df.to_csv('reduced_final_df.csv', index=False)

# %%
filtered_counts = unique_counts[unique_counts < 30000]
filtered_counts
# Out:
# DIAGNOSIS
# PNEUMONIA                              29100
# SEPSIS                                 22429
# CONGESTIVE HEART FAILURE               15755
# CORONARY ARTERY DISEASE                11770
# CHEST PAIN                             10583
#                                        ...
# RIGHT WRISTS FRACTURE                      1
# MENINGIOMA, RIGHT SIDE/SDA                 1
# HYPOTENSION;SMALL BOWEL OBSTRUCTION        1
# BREAST CANCER;RECONSTRUCTION,BREAST        1
# OLIGODENDROGLIOMA RIGHT /SDA               1
# Name: count, Length: 8866, dtype: int64
